# %% [markdown]
# # Diese Sitzung wird noch vorbereitet
#
# Das Material zu dieser Sitzung wird **vor der jeweiligen Veranstaltung** hier
# freigeschaltet.
#
# Schau kurz vor der Sitzung noch einmal vorbei — dann findest du hier das
# Notebook zum Mitmachen.
